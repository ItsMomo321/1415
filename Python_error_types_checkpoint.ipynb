# %% [markdown]
# <a href="https://colab.research.google.com/github/ItsMomo321/1415/blob/main/Python_error_types_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rectify the code in each cell and **explain the error in comments**

# %% [markdown]
# ### index error

# %%
mylist=[14, "hello", 967]
mylist[2]#il n'y a que 3 choses
# Out:
# 967

# %%
import pandas as pd #sans majuscules
import numpy as np #sans majuscules

# %% [markdown]
# # syntax error

# %%
print"python errors"#sans majuscule
# Out:
# python errors

# %% [markdown]
# # key error

# %%
mydictionnary={True:"hello",False:"bye", '3':"python"}
mydictionnary[True]# Sans guillemets
# Out:
# 'hello'

# %% [markdown]
# # indentation error

# %%
i=14
while i<78:
  print(i)# Erreur d'espace
i+=1
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# ...

# %% [markdown]
# # StopIteration

# %%
it=iter([1,2,3])
next(it)
next(it)
next(it)
#Il n'y a que 3 items
# Out:
# 3

# %% [markdown]
# # TypeError

# %%
15+15#Il faut enlever des crochets car il ne compte que les str
# Out:
# 30

# %% [markdown]
# # ValueError

# %%
int("3")# On ne peut mettre que des nombres\chiffres
# Out:
# 3

# %% [markdown]
# # NameError

# %%
"python"#Avec les guillemets
# Out:
# 'python'

# %% [markdown]
# # ZeroDivisionError

# %%
x=19/3 #On ne peut pas diviser par 0
